# %%
import pandas as pd
import bias_corr

# %%
vlbi = pd.read_csv('vlbi_20deg.csv')
vlbi_5p = vlbi[(vlbi['astrometric_params_solved']==31)]
print(len(vlbi_5p))

phot_g_mean_mag = vlbi_5p['phot_g_mean_mag']  
nu_eff = vlbi_5p['nu_eff_used_in_astrometry'] 
beta = vlbi_5p['ecl_lat']

path = 'coefficients.txt' 
vlbi_5p['bias'] = 0.001*bias_corr.calc_pzpo(phot_g_mean_mag,nu_eff,beta,path) 
vlbi_5p['plx_corr'] = vlbi_5p['parallax'] - vlbi_5p['bias'] 

vlbi_5p.loc[:,['parallax','plx_corr']]
# Out:
# 54
# /var/folders/ky/znh530q519g92_17nny_1cq40000gn/T/ipykernel_84045/1292898361.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vlbi_5p['bias'] = 0.001*bias_corr.calc_pzpo(phot_g_mean_mag,nu_eff,beta,path)
# /var/folders/ky/znh530q519g92_17nny_1cq40000gn/T/ipykernel_84045/1292898361.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vlbi_5p['plx_corr'] = vlbi_5p['parallax'] - vlbi_5p['bias']
#      parallax   plx_corr
# 1    1.953213   2.014597
# 3    0.419180   0.482471
# ...

# %%
print(list(b)[0])
# Out:
# 40.35090316778006
